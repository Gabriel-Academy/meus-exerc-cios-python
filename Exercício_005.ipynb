# %%
a= int(input('Digite um valor: '))
print(f'Olá! Após analisar O valor {a}, consta que seu antecessor é {a-1} e o sucessor é {a+1}.')
# Out:
# Digite um valor: 80
# Olá! Após analisar O valor 80, consta que seu antecessor é 79 e o sucessor é 81.
