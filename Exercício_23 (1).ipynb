# %%
# True = Verdadeiro / False = Falso

n = str(input('Olá, digite o nome da cidade que você nasceu: ')).strip()
n2 = n.lower()
print(f' A cidade que você digitou, começa com a palavra "Santo"? {n2[:5]== "santo"}')
# Out:
# Olá, digite o nome da cidade que você nasceu: SaNtO Amaro
#  A cidade que você digitou, começa com a palavra "Santo"? True
