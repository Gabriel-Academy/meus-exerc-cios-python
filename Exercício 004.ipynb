# %%
a= input('Digite algo: ')
print('O tipo primitivo do valor é', type(a))
print('Só tem espaços? ', a.isspace())
print('É alfabético?', a.isalpha())
print('É alfa númerico?', a.isalnum())
print('Está em maiúscula', a.isupper())
print('É um número?', a.isnumeric())
print('Está em minúsculo?', a.islower())
print('Está capitalizado?', a.istitle())
# Out:
# Digite algo: David01
# O tipo primitivo do valor é <class 'str'>
# Só tem espaços?  False
# É alfabético? False
# É alfa númerico? True
# Está em maiúscula False
# É um número? False
# Está em minúsculo? False
# Está capitalizado? True
