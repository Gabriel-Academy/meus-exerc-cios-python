# %%
from random import shuffle

n = str(input('Digite o primeiro nome: '))
n2 = str(input('Digite o segundo nome: '))
n3 = str(input('Digite o terceiro nome: '))
n4 = str(input('Dgite o quarto nome: '))
lista = [n, n2, n3, n4]
shuffle(lista)
print('A ordem da apresentação será')
print(lista)
# Out:
# Digite o primeiro nome: Adriano
# Digite o segundo nome: Adriana
# Digite o terceiro nome: João
# Dgite o quarto nome: Maria
# A ordem da apresentação será
# ['Adriano', 'João', 'Adriana', 'Maria']
