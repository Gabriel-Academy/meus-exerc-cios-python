# %%
print('-='*10)
print('Contador de 10 termos de uma PA')
print('-='*10)
2
n = int(input('Digite o primeiro termo: '))

n2 = int(input('Digite a razão: '))

decimo = n + (10-1) * n2

for c in range(n,decimo,n2):
  print(c, end=' > ')
print('FIM')
# Out:
# -=-=-=-=-=-=-=-=-=-=
# Contador de 10 termos de uma PA
# -=-=-=-=-=-=-=-=-=-=
# Digite o primeiro termo: 0
# Digite a razão: 2
# 0 > 2 > 4 > 6 > 8 > 10 > 12 > 14 > 16 > FIM
