# %%
# A cidade possui 'santo' = True, não possui 'False'

n = input('Olá, digite o nome da cidade que você nasceu: ').sprit()
n2 = n.lower()
print(f'A cidade {'santo' in (n2)} em seu nome.')
# Out:
# Olá, digite o nome da cidade que você nasceu: Espirito SantO
# A cidade espirito santo True em seu nome.
