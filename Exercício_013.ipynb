# %%
n= float(input('Olá, digite o valor do seu salário R% '))
n2= float(input('Digite a porcentagem do aumento dado % '))
n3= (n*n2) / 100
print(f'O seu salário é R% {n:.2f}, o aumento foi de {n2:.2f}%. Por fim, seu salário será de: {n+n3:.2f}. Parabés pelo aumento!')
# Out:
# Olá, digite o valor do seu salário R% 1621
# Digite a porcentagem do aumento dado % 10
# O seu salário é R% 1621.00, o aumento foi de 10.00%. Por fim, seu salário será de: 1783.10. Parabés pelo aumento!
