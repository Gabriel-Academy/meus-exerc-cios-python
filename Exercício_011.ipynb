# %%
n= float(input('Qual a largura da sua parede? '))
n2= float(input('Qaul a altura da sua parede? '))
n3= n*n2
print(f'A área do local que será pintado é de {n3}m². Será necessário {n3/2}L de tinta para pintar a área por completo.')
# Out:
# Qual a largura da sua parede? 6
# Qaul a altura da sua parede? 6
# A área do local que será pintado é de 36.0m². Será necessário 18.0L de tinta para pintar a área por completo.
