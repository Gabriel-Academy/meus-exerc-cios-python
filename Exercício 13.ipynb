# %%
a1 = float(input("Digite o valor do seu salário: "))
a2 = (a1*15) / 100
a3 = print(f'O valor do seu salário, com o acréssimo de 15% é: {a2+a1}')
# Out:
# Digite o valor do seu salário: 1621
# O valor do seu salário, com o acréssimo de 15% é: 1864.15
