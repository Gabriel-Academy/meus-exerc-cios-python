# %%
soma = 0
cont = 0
for c in range(1, 501, 2):
  if c % 3 == 0:
    soma = soma + c
    cont = cont + 1
print(f'A soma de todos os {cont} números executado é igual a {soma}.')
# Out:
# A soma de todos os 83 números executado é igual a 20667.
