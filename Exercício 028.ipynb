# %%
import random

n = float(input('Em qual número estou pensando? (de 0 a 2) '))

num = random.randint(0, 2)

if n == num:

  print('PARABÉNS, VOCÊ ACERTOU!')

else:

  print('Infelizmente você não acetou. Por favor tente novamente, você consegue!')
# Out:
# Em qual número estou pensando? (de 0 a 10) 2
# Infelizmente você não acetou. Por favor, tente novamente, você consegue!
