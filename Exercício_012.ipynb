# %%
n= float(input('Olá, digite o valor total do produto R$ '))
n2= (n*5) / 100
print(f'O valor do produto é R$ {n:.2f}, com 5% de desconto fica por: R% {n-n2:.2f}')
# Out:
# Olá, digite o valor total do produto R$ 50
# O valor do produto é R$ 50.00, com 5% de desconto fica por: R% 47.50
