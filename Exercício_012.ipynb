# %%
n= float(input('Olá, digite o valor total do produto R$ '))
n1= float(input('Digite o valor da porcentagem dada % '))
n2= (n*n1) / 100
print(f'O valor do produto é R$ {n:.2f}, com {n1:.2f}% de desconto fica por: R% {n-n2:.2f}')
# Out:
# Olá, digite o valor total do produto R$ 10000
# Digite o valor da porcentagem dada % 13
# O valor do produto é R$ 10000.00, com 13.00% de desconto fica por: 8700.00
