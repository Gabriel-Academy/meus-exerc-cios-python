# %%
n= float(input('Olá, vamos calcular sua média? Me conta a sua primeira nota: '))
n2= float(input('Segunda nota: '))
n3= float(input('Terceira nota: '))
n4= float(input('Quarta nota: '))
s= n+n2+n3+n4
print(f'Vamos avaliar! A sua nota final foi {s:.2f} e sua média é: {s/4:.2f}.')
# Out:
# Olá, vamos calcular sua média? Me conta a sua primeira nota: 8.5
# Segunda nota: 7.4
# Terceira nota: 5.5
# Quarta nota: 9.2
# Vamos avaliar! A sua nota final foi 30.60 e sua média é: 7.65.
