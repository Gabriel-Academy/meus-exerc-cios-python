# %%
n= int(input('Olá, vamos calcular sua média? Me conta a sua primeira nota: '))
n2= int(input('Segunda nota: '))
n3= int(input('Terceira nota: '))
n4= int(input('Quarta nota: '))
s= n+n2+n3+n4
print(f'Vamos avaliar! A sua nota final foi {s} e sua média é: {s/4}.')
# Out:
# Olá, vamos calcular sua média? Me conta a sua primeira nota: 8
# Segunda nota: 7
# Terceira nota: 9
# Quarta nota: 6
# Vamos avaliar! A sua nota final foi 30 e sua média é: 7.5.
