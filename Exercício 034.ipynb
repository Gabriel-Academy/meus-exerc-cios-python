# %%
n = float(input('Digite o valor do seu salário: '))
print(f'Show, vamos calcular as porcentagens do seu salário de R${n}')
if n <=1250:
  n2 = (n*15) / 100
else:
  n2 = (n*10) / 100
print(f' O valor do seu salário ficou por {n2+n}')
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Avaliador de Triângulos
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Digite o primeiro comprimento: 2
# Digite o segundo comprimento: 4
# Dgite o terceiro comprimento: 6
# Os comprimentos acima NÃO podem formar um triângulo
