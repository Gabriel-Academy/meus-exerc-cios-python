# %%
n = input('Digite seu nome: ')

#Tudo em maiúsculo

print(n.upper())

#Tudo em minúsculo

print(n.lower())

#Frase contada (sem espaços)

print(len(n.strip()))

#Quantas letras tem a primeira frase

n2 = n
div = n.split()
print(len(div[0]))
# Out:
# Digite seu nome: Carlos Miguel dos Santos
# CARLOS MIGUEL DOS SANTOS
# carlos miguel dos santos
# 24
# 6
