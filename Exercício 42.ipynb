# %%
print('-='*20)
print('Avaliador de Triângulos')
print('-='*20)
n = float(input('Digite o primeiro comprimento: '))
n2 = float(input('Digite o segundo comprimento: '))
n3 = float(input('Dgite o terceiro comprimento: '))
if n < n2 + n3 and n2 < n + n3 and n3 < n + n2:
 print('O segmento acima pode formar um triãngulo ', end='')
 if n == n2 == n3:
  print('EQUILÁTERO')
 elif n != n2 != n3 != n:
  print('ESCALENO')
 else:
  print('ISÓCELES')
else:
  print('O seguimento acima não pode formar um triângulo.')
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Avaliador de Triângulos
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Digite o primeiro comprimento: 9
# Digite o segundo comprimento: 1
# Dgite o terceiro comprimento: 7
# O seguimento acima não pode formar um triângulo.
