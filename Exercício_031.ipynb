# %%
n = float(input('Digite a distancia da sua viagem: '))
print(f'Você está prestes a iniciar uma vagem de {n}Km')
if n <=200:
  n2 = n * 0.50
else:
  n2 = n * 0.45
print(f'O valor da sua viagem ficou por R${n2}')
# Out:
# Digite a distancia da sua viagem: 210
# Você está prestes a iniciar uma vagem de 210.0Km
# O valor da sua viagem ficou por R$94.5
