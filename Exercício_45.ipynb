# %%
from random import randint
from time import sleep
print('-'*10)
print('JOKENPÔ')
print('-'*10)
print('''Escolha uma das opções abaixo!
[0] Pedra
[1] Papel
[2] Tesoura''')
jogador = int(input('Digite sua opção: '))
print('JO')
sleep(0.6)
print('KEN')
sleep(0.6)
print('PÔ')
sleep(0.6)
print('-='*10)
print(f'O jogador escolheu: {lista[jogador]}')
lista = ('Pedra', 'Papel', 'Tesoura')
máquina = randint(0,2)
print(f'A máquina escolheu: {lista[máquina]}')
print('-='*10)
if máquina == 0: #Pedra
    if jogador == 0:
      print('EMPATOU!')
    elif jogador == 1:
      print('Você VENCEU!')
    elif jogador == 2:
      print('Você PERDEU!')


elif máquina == 1: #Papel
  if jogador == 0:
    print('Vcoê PERDEU!')
  elif jogador == 1:
    print('Você EMPATOU!')
  elif jogador == 2:
    print('Você VENCEU')


elif máquina == 2: #Tesoura
  if jogador == 0:
    print('Você GANHOU!')
  if jogador == 1:
    print('Você PERDEU!')
  if jogador == 2:
    print('Você EMPATOU!')
# Out:
# ----------
# JOKENPÔ
# ----------
# Escolha uma das opções abaixo!
# [0] Pedra
# [1] Papel
# [2] Tesoura
# Digite sua opção: 2
# JO
# KEN
# PÔ
# -=-=-=-=-=-=-=-=-=-=
# O jogador escolheu: Tesoura
# A máquina escolheu: Papel
# -=-=-=-=-=-=-=-=-=-=
# Você VENCEU
