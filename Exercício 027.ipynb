# %%
n = str(input('Digite seu nome: ')).strip()
n2 = n.split()
print(f'O seu primeiro nome é: {n2[0]}')
print(f'O seu último nome é: {n2[len(n2)-1]}')
# Out:
# Digite seu nome: Joaquim José da Silva Xavier
# O seu primeiro nome é: Joaquim
# O seu último nome é: Xavier
