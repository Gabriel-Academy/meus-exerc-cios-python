# %%
n = float(input("Digite um valor fraciondo: "))
print(f'Olá! o número digitado {n} em sua porção inteira é igual a {math.trunc (n)}')
# Out:
# Digite um valor fraciondo: 6.127
# Olá! o número digitado 6.127 em sua porção inteira é igual a 6
