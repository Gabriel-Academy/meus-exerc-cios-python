# %%
n= input('Olá, em qual dia você nasceu? ')
n2= input('De qual mês? ')
n3= input('De qual ano? ')
print(f'Show! Você nasceu em {n}/{n2}/{n3}.')
# Out:
# Olá, em qual dia você nasceu? 15
# De qual mês? 08
# De qual ano? 2000
# Show! Você nasceu em 15/08/2000.
