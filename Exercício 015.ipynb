# %%
n = int(input('Por quantos dias o carro foi alugado? '))
n2 = float(input('Quantos KM foi percorrido com o carro? '))
n3 = (n * 60 + n2 * 0.15)
print(f'O valor total a pagar é de R$ {n3:.2f}')
# Out:
# Por quantos dias o carro foi alugado? 8
# Quantos KM foi percorrido com o carro? 720
# O valor total a pagar é de R$ 588.00
