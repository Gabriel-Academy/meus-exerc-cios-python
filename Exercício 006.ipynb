# %%
n= int(input('Olá, digite um número, por favor: '))
n2= n**(1/2)
print(f'Perfeito! O valor digitado foi {n}, o dobro deste valor é igual a {n*2}, e sua raiz é igual a {n2 :.2f}.')
# Out:
# Olá, digite um número, por favor: 10
# Perfeito! O valor digitado foi 10, o dobro deste valor é igual a 20, e sua raiz é igual a 3.16, coreto?
