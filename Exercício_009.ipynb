# %%
n= int(input('Olá, bem-vindo a tabuada! Digite o valor que deseja saber a tabuada: '))
print('-' * 12)
print(f'{n} x {1} = {n*1}')
print(f'{n} x {2} = {n*2}')
print(f'{n} x {3} = {n*3}')
print(f'{n} x {4} = {n*4}')
print(f'{n} x {5} = {n*5}')
print(f'{n} x {6} = {n*6}')
print(f'{n} x {7} = {n*7}')
print(f'{n} x {8} = {n*8}')
print(f'{n} x {9} = {n*9}')
print(f'{n} x {10} = {n*10}')
print('-' * 12)

print('Bons estudos!')
# Out:
# Olá, bem-vindo a tabuada! Digite o valor que deseja saber a tabuada: 5
# ------------
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# ------------
# Bons estudos!
