# %%
n = int(input('Digite um valor: '))
n2 = int(input('Digite outro valor: '))
if n > n2:
  print('O primeiro valor é maior que o segundo valor')
elif n2 > n:
  print('O segundo valor é maior que o primeiro valor.')
elif n == n2:
  print('''Não existe valor maior entre os dois números digitados, ambos possuem o mesmo valor.''')
# Out:
# Digite um valor: 40
# Digite outro valor: 50
# O segundo valor é maior que o primeiro valor.
