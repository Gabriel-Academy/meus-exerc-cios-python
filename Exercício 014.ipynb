# %%
n = float(input('Digite a tenperatura (celsius) atual: '))
n2 = n * 1.8 + 32
print(f'{n}°C convertendo para Fahrenheit é igual {n2}F!')
# Out:
# Digite a tenperatura (celsius) atual: 27
# 27.0°C convertendo para Fahrenheit é igual 80.6F!
