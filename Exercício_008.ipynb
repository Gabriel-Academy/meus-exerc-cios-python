# %%
n= int(input('Olá, digite a metragem a ser convertida: '))
print(f'Perfeito. A conversão da metragem digitada é igual a {n*100} centímetros e {n*1000} milímetros.')
# Out:
# Olá, digite a metragem a ser convertida: 48
# Perfeito. A conversão da metragem digitada é igual a 4800 centímetros e 48000 milímetros.
