# %%
n = int(input('Digite o ano do seu nasciumeto: '))
n2 = int(input('Informe o ano atual: '))
n3 = n2 - n
if n3 < 18:
  print(f'Com {n3} anos, ainda faltam {18-n3} anos para você se alistar no Exército! Boa sorte.')
elif n3 == 18:
  print(f'''Com {n3} anos, você já deve se alistar. Procure uma Junta Militar mais proxima
para obter mais informações.''')
else:
  print(f'''Com {n3} anos, você PASSOU {n3-18} anos do prazo de alistamento, procure uma Junta Militar o mais
rápido possível.''')
# Out:
# Digite o ano do seu nasciumeto: 2010
# Informe o ano atual: 2026
# Com 16 anos, ainda faltam 2 anos para você se alistar no Exército! Boa sorte.
