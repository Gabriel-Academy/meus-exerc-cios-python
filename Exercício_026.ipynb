# %%
n = str(input('Digte o seu nome: ')).strip()
n2 = n.lower()
print(f'A sua palavra contém: {n2.count('a')} letras "A"')
print(f'A primeira letra "A" está na posição: {n2.find('a')+1}')
print(f'A última letra "A" da sua palavra está na posição: {n2.rfind('a')+1}')
# Out:
# Digte o seu nome:            Abacaxi Verde e Azul
# A sua palavra contém: 4 letras "A"
# A primeira letra "A" está na posição: 1
# A última letra "A" da sua palavra está na posição: 17
