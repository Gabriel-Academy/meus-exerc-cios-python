# %%
from random import choice

n = str(input('Digite o primeiro nome: '))

n2 = str(input('Digite o segundo nome: '))

n3 = str(input('Digite o terceiro nome: '))

n4 = str(input('Digite o quarto nome: '))

lista = [n, n2, n3, n4]

escolhido = choice ( lista )

print(f'O nome escolhido foi: {escolhido}')
# Out:
# Digite o primeiro nome: Pedro
# Digite o segundo nome: Mario
# Digite o terceiro nome: João
# Digite o quarto nome: Ana
# O nome escolhido foi: Ana
