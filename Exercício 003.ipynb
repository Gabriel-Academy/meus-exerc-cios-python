# %%
n= int(input('Olá, digite um número, por favor: '))
n2= int(input('Digite mais um número, por favor: '))
s= n+n2
print('Perfeito! A soma dos valores é igual a', s)
# Out:
# Olá, digite um número, por favor: 82
# Digite mais um número, por favor: 90
# Perfeito! A soma dos valores é igual a 172
