# %%
n= float(input('Olá, bem-vindo a sua carteira digital de conversão em dólar! Quanto você deseja converter? R$ '))
n1= n / 5.06
print(f'Com R$ {n} você pode comprar US$ {n1 :.2f}')
# Out:
# Olá, bem-vindo a sua carteira digital de conversão em dólar! Quanto você deseja converter? R$ 1621
# Com R$ 1621.0 você pode comprar US$ 320.36
